# %%
# Import the random module
from citipy import citipy
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create 2,000 latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(11.547858895544948, 33.13516600471351), (84.74956246962515, -166.8329595234512), (-89.48218456693911, -119.28204000191593), (-8.542730782367059, 51.41862945658278), (-62.67585703593464, -123.14013891548244), (-42.3222170577218, -48.49195600824285), (-22.793419347964132, 141.84553515076317), (34.715034143287426, 137.29888470092072), (-46.40556187388451, 96.8398710538192), (55.58810474485452, 115.36675583882192), (-29.3820786324166, 112.68334242680089), (-47.83290571747889, -63.94111004255494), (-55.917921947394404, 38.582412374529724), (-53.73270675866249, 167.80067646201627), (-76.98860476566905, 156.64352775050367), (-18.39855486068278, -164.1934608153957), (-34.5082315606296, -73.16486109092526), (14.766692070193983, -168.6076198211838), (2.999354777661466, 114.56001426016684), (88.4476475124207, 47.53027316553019), (-3.6354030854311077, 150.11815822660952), (-76.2204906648181, 40.18910912449397), (28.436878259319542, -153.82248319072107), (-27.616673189990735, 69.83675330054982), (-29.89480874154831, -32.544917234078554), (45.07180162586016, 136.2118887213578), (-36.6606340864284, -83.31777554917375), (36.565193199672024, -72.11607783503963), (89.63590645130435, -46.88683991326977), (86.00721438149509, 115.21689385519255), (67.14314225894469, 116.94630022351146), (26.91076794208699, 155.05951481409744), (76.81386129067917, -146.49925773750374), (58.27313067942612, -82.41225950513095), (64.30321478171444, 53.586454560020684), (41.423931427952766, -48.575354725275076), (-13.998427875570968, -174.47264095070918), (-3.7733693523195484, -65.35296795790458), (-2.794630902806375, -99.22389211538255), (-80.35590480935385, -113.43926365959987), (-57.38162914654679, 53.53421735457064), (80.06174295075252, 14.726878882147957), (67.52666675150223, -52.744538514158805), (39.42720141364262, 34.42763801066641), (40.44115149441808, -85.94529124628487), (-72.96921056981839, -146.27684095362926), (-64.4575155257676, 142.19974127539632), (-64.17266670127435, 36.061694347743526), (76.3856815849638, 157.00347417767006), (88.44154080318324, -17.870794079983767), (-70.79881709788083, 174.7944263997059), (23.069670892899964, -60.15825876393306), (49.47407238989905, 2.8445594689147526), (11.184182302128164, -47.9041378993698), (-79.96071026483457, 19.642417648187063), (55.25649284708385, -153.1978531886161), (-67.36608805420275, -145.33340863053053), (66.36371032365759, 58.63886743336417), (-29.70668204771505, 57.72341406461254), (77.88826284951045, -4.529083501339329), (56.43558371632881, -157.4518031070911), (57.22462052277419, -47.05665411246676), (-79.71537446353325, 12.41038207856974), (-4.953970957925719, -15.416288336532801), (-43.67455730846184, -58.02991634781745), (73.34054728540355, -163.07503158736273), (-77.4627331079025, 112.54881776842961), (-30.69831864309552, -15.77936565340093), (-74.74875068743162, 178.16530911616564), (84.62280083269331, 99.45958055657638), (56.03534902473342, -171.54725128336437), (46.708063278882065, 123.0164122393017), (43.350393768337625, 179.42950376163856), (31.326166265425513, 93.71721713507822), (48.18008301320393, -126.09267631779142), (-29.92385974214053, -116.41666309670926), (53.590270573528926, 166.40589402113403), (-8.227644012916002, 74.43327332196071), (36.400536666591535, -164.95064274759147), (52.12010722292331, -11.290061661225593), (55.10627336397695, 126.43342222342022), (-49.87651223507722, -21.40717423373343), (-34.896178724413524, 62.87454963223942), (-78.26476089675276, 39.55139522487028), (26.089690040613803, -73.91094355667317), (54.11985808231432, -21.47736702920517), (75.90636184737753, -94.23757694064948), (29.350420319130436, -176.71664472344025), (-51.954679281976844, -33.91480482774142), (79.27668401003163, -177.26768278498727), (-52.333607398259566, -6.673087797671798), (-38.94193860171962, 144.19490415395398), (-14.597083289874647, -167.46494212997104), (79.46154666751818, -23.323414559758362), (13.534274824387609, -25.412343375353316), (74.19838621998937, -100.30871356834344 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# Print to city to confirm sufficient count
len(cities)
# Out:
# 740

# %%
# Perform an API call with the OpenWeatherMap

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count += 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the 350N and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lon": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description })
        
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete       ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 2 | marabba
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | ambilobe
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | rocha
# Processing Record 7 of Set 2 | mount isa
# Processing Record 8 of Set 2 | tahara
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | taksimo
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | miri
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | kavieng
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | plastun
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | brigantine
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | nyurba
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | ukhta
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 2 | tefe
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | kangaatsiaq
# Processing Record 40 of Set 2 | yerkoy
# Processing Record 41 of Set 2 | kokomo
# Processing Record 42 of Set 2 | mataura
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | the valley
# Processing Record 48 of Set 2 | compiegne
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | synya
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | klaksvik
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | necochea
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | tailai
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | ucluelet
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | ovsyanka
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | leopold
# Processing Record 27 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | falun
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | quelimane
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | njombe
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | bowen
# Processing Record 39 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | vila franca do campo
# Processing Record 42 of Set 3 | san policarpo
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | alice springs
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | helena
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | hjelset
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | mirnyy
# Processing Record 2 of Set 4 | atuona
# Processing Record 3 of Set 4 | ettaiyapuram
# Processing Record 4 of Set 4 | san quintin
# Processing Record 5 of Set 4 | kholodnyy
# Processing Record 6 of Set 4 | port augusta
# Processing Record 7 of Set 4 | ushuaia
# Processing Record 8 of Set 4 | ternate
# Processing Record 9 of Set 4 | magistralnyy
# Processing Record 10 of Set 4 | paytug
# City not found. Skipping...
# Processing Record 11 of Set 4 | kargasok
# Processing Record 12 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | vikhorevka
# Processing Record 15 of Set 4 | sistranda
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | selyatino
# Processing Record 19 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 4 | codrington
# Processing Record 21 of Set 4 | grindavik
# Processing Record 22 of Set 4 | ofunato
# Processing Record 23 of Set 4 | tshikapa
# Processing Record 24 of Set 4 | benalla
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | kimparana
# Processing Record 27 of Set 4 | karasjok
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | eha amufu
# Processing Record 30 of Set 4 | takoradi
# Processing Record 31 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | nchelenge
# Processing Record 33 of Set 4 | turukhansk
# Processing Record 34 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 4 | marfino
# Processing Record 36 of Set 4 | jaciara
# Processing Record 37 of Set 4 | venice
# Processing Record 38 of Set 4 | tehri
# Processing Record 39 of Set 4 | roald
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | moundsville
# Processing Record 42 of Set 4 | kankon
# Processing Record 43 of Set 4 | beloha
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | vaini
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | grand gaube
# Processing Record 48 of Set 4 | rorvik
# Processing Record 49 of Set 4 | wahpeton
# Processing Record 50 of Set 4 | marystown
# Processing Record 1 of Set 5 | ha tinh
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | aberdeen
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | whitianga
# Processing Record 8 of Set 5 | campbellsville
# Processing Record 9 of Set 5 | butaritari
# Processing Record 10 of Set 5 | garden city
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | najran
# Processing Record 13 of Set 5 | macamic
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | shumikhinskiy
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | sembe
# Processing Record 20 of Set 5 | lompoc
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | korla
# Processing Record 24 of Set 5 | chavakkad
# Processing Record 25 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 5 | bairiki
# Processing Record 27 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | letenye
# Processing Record 29 of Set 5 | buala
# Processing Record 30 of Set 5 | solnechnyy
# Processing Record 31 of Set 5 | richards bay
# Processing Record 32 of Set 5 | hami
# Processing Record 33 of Set 5 | manadhoo
# Processing Record 34 of Set 5 | bethel
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | bogacs
# Processing Record 41 of Set 5 | tuktoyaktuk
# Processing Record 42 of Set 5 | peterhead
# Processing Record 43 of Set 5 | eyl
# Processing Record 44 of Set 5 | sao francisco
# Processing Record 45 of Set 5 | salvador
# Processing Record 46 of Set 5 | mogadishu
# Processing Record 47 of Set 5 | westport
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | kilinochchi
# Processing Record 50 of Set 5 | biryukove
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | sayyan
# Processing Record 3 of Set 6 | tilichiki
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | esperance
# Processing Record 6 of Set 6 | tuy hoa
# Processing Record 7 of Set 6 | mancio lima
# Processing Record 8 of Set 6 | awjilah
# Processing Record 9 of Set 6 | offa
# Processing Record 10 of Set 6 | ndungu
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | saint george
# Processing Record 13 of Set 6 | natal
# Processing Record 14 of Set 6 | svetlogorsk
# Processing Record 15 of Set 6 | misratah
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | kenda
# Processing Record 18 of Set 6 | tobol
# Processing Record 19 of Set 6 | katsuura
# Processing Record 20 of Set 6 | olafsvik
# Processing Record 21 of Set 6 | nauta
# Processing Record 22 of Set 6 | aquiraz
# Processing Record 23 of Set 6 | goderich
# Processing Record 24 of Set 6 | bandarbeyla
# Processing Record 25 of Set 6 | almaznyy
# Processing Record 26 of Set 6 | gamba
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | qaanaaq
# Processing Record 30 of Set 6 | brae
# Processing Record 31 of Set 6 | sur
# Processing Record 32 of Set 6 | alofi
# Processing Record 33 of Set 6 | chumikan
# Processing Record 34 of Set 6 | tual
# Processing Record 35 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 6 | pombas
# Processing Record 37 of Set 6 | uglegorsk
# Processing Record 38 of Set 6 | roebourne
# Processing Record 39 of Set 6 | ribeira grande
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | faya
# Processing Record 44 of Set 6 | kaeo
# Processing Record 45 of Set 6 | casper
# Processing Record 46 of Set 6 | zaozhuang
# Processing Record 47 of Set 6 | taybad
# Processing Record 48 of Set 6 | hambantota
# Processing Record 49 of Set 6 | mnogovershinnyy
# Processing Record 50 of Set 6 | teguldet
# Processing Record 1 of Set 7 | sorland
# Processing Record 2 of Set 7 | novopskov
# Processing Record 3 of Set 7 | aripuana
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | jurado
# Processing Record 8 of Set 7 | diego de almagro
# Processing Record 9 of Set 7 | asau
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | high level
# Processing Record 12 of Set 7 | tasiilaq
# Processing Record 13 of Set 7 | freeport
# Processing Record 14 of Set 7 | abu kamal
# Processing Record 15 of Set 7 | coquimbo
# Processing Record 16 of Set 7 | san carlos de bariloche
# Processing Record 17 of Set 7 | hervey bay
# Processing Record 18 of Set 7 | aksehir
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | baragua
# Processing Record 21 of Set 7 | los llanos de aridane
# Processing Record 22 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | hay river
# Processing Record 25 of Set 7 | buraydah
# Processing Record 26 of Set 7 | mongar
# Processing Record 27 of Set 7 | ust-maya
# Processing Record 28 of Set 7 | ponta do sol
# Processing Record 29 of Set 7 | racine
# Processing Record 30 of Set 7 | grootfontein
# Processing Record 31 of Set 7 | charagua
# Processing Record 32 of Set 7 | iwanai
# Processing Record 33 of Set 7 | gorin
# Processing Record 34 of Set 7 | east london
# Processing Record 35 of Set 7 | polunochnoye
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | coahuayana
# Processing Record 38 of Set 7 | mayor pablo lagerenza
# Processing Record 39 of Set 7 | adeje
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | new plymouth
# Processing Record 42 of Set 7 | bambanglipuro
# Processing Record 43 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 7 | kennett
# Processing Record 46 of Set 7 | ingham
# Processing Record 47 of Set 7 | kudahuvadhoo
# Processing Record 48 of Set 7 | kodinsk
# Processing Record 49 of Set 7 | mahebourg
# Processing Record 50 of Set 7 | caravelas
# Processing Record 1 of Set 8 | south venice
# Processing Record 2 of Set 8 | darnah
# Processing Record 3 of Set 8 | tahta
# Processing Record 4 of Set 8 | harlingen
# Processing Record 5 of Set 8 | pangnirtung
# Processing Record 6 of Set 8 | praya
# Processing Record 7 of Set 8 | mar del plata
# Processing Record 8 of Set 8 | mackay
# Processing Record 9 of Set 8 | sanislau
# Processing Record 10 of Set 8 | dryden
# Processing Record 11 of Set 8 | mecca
# Processing Record 12 of Set 8 | aktash
# Processing Record 13 of Set 8 | villanueva
# Processing Record 14 of Set 8 | lumeje
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | rio grande
# Processing Record 17 of Set 8 | vung tau
# Processing Record 18 of Set 8 | sambava
# Processing Record 19 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 20 of Set 8 | ballina
# Processing Record 21 of Set 8 | port blair
# Processing Record 22 of Set 8 | huarmey
# Processing Record 23 of Set 8 | mocuba
# Processing Record 24 of Set 8 | camabatela
# Processing Record 25 of Set 8 | robinson
# Processing Record 26 of Set 8 | beni mazar
# Processing Record 27 of Set 8 | emerald
# Processing Record 28 of Set 8 | nanakuli
# Processing Record 29 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | port shepstone
# Processing Record 32 of Set 8 | shush
# Processing Record 33 of Set 8 | maningrida
# Processing Record 34 of Set 8 | shcholkine
# City not found. Skipping...
# Processing Record 35 of Set 8 | dibulla
# Processing Record 36 of Set 8 | bridgton
# Processing Record 37 of Set 8 | cabo san lucas
# Processing Record 38 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 8 | san pedro
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | kitami
# Processing Record 43 of Set 8 | amahai
# Processing Record 44 of Set 8 | arrifes
# Processing Record 45 of Set 8 | angoram
# Processing Record 46 of Set 8 | shirdi
# Processing Record 47 of Set 8 | aklavik
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | goreloye
# Processing Record 50 of Set 8 | benghazi
# Processing Record 1 of Set 9 | hualmay
# Processing Record 2 of Set 9 | santa rosa
# Processing Record 3 of Set 9 | camacha
# Processing Record 4 of Set 9 | saint-francois
# Processing Record 5 of Set 9 | nelson bay
# Processing Record 6 of Set 9 | edinet
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | svetlaya
# Processing Record 9 of Set 9 | poum
# Processing Record 10 of Set 9 | nemuro
# Processing Record 11 of Set 9 | stari bohorodchany
# Processing Record 12 of Set 9 | lagoa
# Processing Record 13 of Set 9 | krivodanovka
# Processing Record 14 of Set 9 | amarpatan
# Processing Record 15 of Set 9 | chakia
# Processing Record 16 of Set 9 | sechura
# Processing Record 17 of Set 9 | saint cloud
# Processing Record 18 of Set 9 | alice
# Processing Record 19 of Set 9 | beboto
# Processing Record 20 of Set 9 | peachland
# Processing Record 21 of Set 9 | warrnambool
# Processing Record 22 of Set 9 | seoul
# Processing Record 23 of Set 9 | santa
# Processing Record 24 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 25 of Set 9 | sonoita
# Processing Record 26 of Set 9 | ayan
# Processing Record 27 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 9 | faanui
# Processing Record 29 of Set 9 | lucea
# Processing Record 30 of Set 9 | yazd
# Processing Record 31 of Set 9 | beirut
# Processing Record 32 of Set 9 | robertson
# Processing Record 33 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 9 | ahuimanu
# Processing Record 35 of Set 9 | kamenka
# Processing Record 36 of Set 9 | esso
# Processing Record 37 of Set 9 | storforshei
# Processing Record 38 of Set 9 | young
# Processing Record 39 of Set 9 | camopi
# Processing Record 40 of Set 9 | novyy urengoy
# Processing Record 41 of Set 9 | tacuarembo
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | camana
# Processing Record 44 of Set 9 | half moon bay
# Processing Record 45 of Set 9 | peniche
# Processing Record 46 of Set 9 | ancud
# Processing Record 47 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 48 of Set 9 | turkan
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 10 | zhigansk
# Processing Record 2 of Set 10 | altay
# Processing Record 3 of Set 10 | puno
# Processing Record 4 of Set 10 | kavaratti
# Processing Record 5 of Set 10 | san vicente
# Processing Record 6 of Set 10 | acari
# Processing Record 7 of Set 10 | canazas
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 10 | lar
# Processing Record 11 of Set 10 | itagiba
# Processing Record 12 of Set 10 | gurupa
# Processing Record 13 of Set 10 | cururupu
# Processing Record 14 of Set 10 | dwarka
# Processing Record 15 of Set 10 | eidsvag
# Processing Record 16 of Set 10 | atasu
# Processing Record 17 of Set 10 | nantucket
# Processing Record 18 of Set 10 | shelburne
# Processing Record 19 of Set 10 | axim
# Processing Record 20 of Set 10 | voznesenye
# Processing Record 21 of Set 10 | kirakira
# Processing Record 22 of Set 10 | carolina
# Processing Record 23 of Set 10 | uglekamensk
# Processing Record 24 of Set 10 | honiara
# Processing Record 25 of Set 10 | saint-georges
# Processing Record 26 of Set 10 | opelousas
# Processing Record 27 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 10 | veraval
# Processing Record 29 of Set 10 | mahibadhoo
# Processing Record 30 of Set 10 | negombo
# Processing Record 31 of Set 10 | fare
# Processing Record 32 of Set 10 | cuamba
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | palmas
# Processing Record 35 of Set 10 | longhua
# Processing Record 36 of Set 10 | marsh harbour
# Processing Record 37 of Set 10 | reinosa
# Processing Record 38 of Set 10 | severnyy
# Processing Record 39 of Set 10 | taoudenni
# Processing Record 40 of Set 10 | uravakonda
# Processing Record 41 of Set 10 | balakhta
# Processing Record 42 of Set 10 | marovoay
# Processing Record 43 of Set 10 | yulara
# Processing Record 44 of Set 10 | rafaela
# Processing Record 45 of Set 10 | antofagasta
# Processing Record 46 of Set 10 | huangmei
# Processing Record 47 of Set 10 | carutapera
# Processing Record 48 of Set 10 | ust-kut
# Processing Record 49 of Set 10 | touba
# Processing Record 50 of Set 10 | frontera
# Processing Record 1 of Set 11 | tucurui
# Processing Record 2 of Set 11 | fallon
# Processing Record 3 of Set 11 | kamaishi
# Processing Record 4 of Set 11 | sheridan
# Processing Record 5 of Set 11 | hirara
# Processing Record 6 of Set 11 | fenoarivo
# Processing Record 7 of Set 11 | george
# Processing Record 8 of Set 11 | puri
# Processing Record 9 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 11 | ouallam
# Processing Record 11 of Set 11 | tabas
# Processing Record 12 of Set 11 | torquay
# Processing Record 13 of Set 11 | conde
# Processing Record 14 of Set 11 | syracuse
# Processing Record 15 of Set 11 | matagami
# Processing Record 16 of Set 11 | tezu
# Processing Record 17 of Set 11 | hagi
# Processing Record 18 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 11 | bezdan
# Processing Record 20 of Set 11 | parrita
# Processing Record 21 of Set 11 | inuvik
# Processing Record 22 of Set 11 | lixourion
# Processing Record 23 of Set 11 | ixtapa
# Processing Record 24 of Set 11 | madrid
# Processing Record 25 of Set 11 | samana
# Processing Record 26 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 11 | saint-pierre
# Processing Record 28 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 11 | burica
# City not found. Skipping...
# Processing Record 30 of Set 11 | crixas
# Processing Record 31 of Set 11 | vila velha
# Processing Record 32 of Set 11 | benguela
# Processing Record 33 of Set 11 | arman
# Processing Record 34 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 11 | lima
# Processing Record 36 of Set 11 | smidovich
# Processing Record 37 of Set 11 | luau
# Processing Record 38 of Set 11 | santa teresa
# Processing Record 39 of Set 11 | pathein
# Processing Record 40 of Set 11 | tashla
# Processing Record 41 of Set 11 | taos
# Processing Record 42 of Set 11 | bonavista
# Processing Record 43 of Set 11 | log
# Processing Record 44 of Set 11 | palmares do sul
# Processing Record 45 of Set 11 | ubinskoye
# Processing Record 46 of Set 11 | kununurra
# Processing Record 47 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 11 | lianzhou
# Processing Record 49 of Set 11 | mbengwi
# Processing Record 50 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 1 of Set 12 | dali
# Processing Record 2 of Set 12 | acarau
# Processing Record 3 of Set 12 | tome
# Processing Record 4 of Set 12 | kalmunai
# Processing Record 5 of Set 12 | ambo
# Processing Record 6 of Set 12 | mareeba
# Processing Record 7 of Set 12 | ionia
# Processing Record 8 of Set 12 | carballo
# Processing Record 9 of Set 12 | noumea
# Processing Record 10 of Set 12 | arlit
# Processing Record 11 of Set 12 | bengkulu
# Processing Record 12 of Set 12 | wesselsbron
# Processing Record 13 of Set 12 | qaqortoq
# Processing Record 14 of Set 12 | kuala pilah
# Processing Record 15 of Set 12 | dongli
# Processing Record 16 of Set 12 | cerritos
# Processing Record 17 of Set 12 | voh
# Processing Record 18 of Set 12 | lorengau
# Processing Record 19 of Set 12 | hun
# Processing Record 20 of Set 12 | tiarei
# Processing Record 21 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 12 | dzhebariki-khaya
# Processing Record 23 of Set 12 | manakara
# Processing Record 24 of Set 12 | rundu
# Processing Record 25 of Set 12 | byron bay
# Processing Record 26 of Set 12 | leshukonskoye
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | ocampo
# Processing Record 29 of Set 12 | deep river
# Processing Record 30 of Set 12 | banka
# Processing Record 31 of Set 12 | ekuvukeni
# Processing Record 32 of Set 12 | muravlenko
# Processing Record 33 of Set 12 | nome
# Processing Record 34 of Set 12 | shancheng
# Processing Record 35 of Set 12 | wagar
# Processing Record 36 of Set 12 | encantado
# Processing Record 37 of Set 12 | atar
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | batagay-alyta
# Processing Record 40 of Set 12 | labuhan
# Processing Record 41 of Set 12 | kiunga
# Processing Record 42 of Set 12 | quatre cocos
# Processing Record 43 of Set 12 | abiy adi
# City not found. Skipping...
# Processing Record 44 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 12 | puerto escondido
# Processing Record 46 of Set 12 | san juan
# Processing Record 47 of Set 12 | saint anthony
# Processing Record 48 of Set 12 | goba
# Processing Record 49 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 12 | mackenzie
# Processing Record 1 of Set 13 | padang
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | athabasca
# Processing Record 4 of Set 13 | sheltozero
# Processing Record 5 of Set 13 | mao
# Processing Record 6 of Set 13 | howard springs
# Processing Record 7 of Set 13 | birjand
# Processing Record 8 of Set 13 | floro
# Processing Record 9 of Set 13 | smoky lake
# Processing Record 10 of Set 13 | iquique
# Processing Record 11 of Set 13 | mantua
# Processing Record 12 of Set 13 | presidencia roque saenz pena
# Processing Record 13 of Set 13 | naqadeh
# Processing Record 14 of Set 13 | dongsheng
# Processing Record 15 of Set 13 | ilebo
# Processing Record 16 of Set 13 | olinda
# Processing Record 17 of Set 13 | katobu
# Processing Record 18 of Set 13 | lodja
# Processing Record 19 of Set 13 | kichmengskiy gorodok
# Processing Record 20 of Set 13 | vysokogornyy
# Processing Record 21 of Set 13 | oistins
# Processing Record 22 of Set 13 | wadi musa
# Processing Record 23 of Set 13 | aleppo
# Processing Record 24 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 13 | karasburg
# Processing Record 26 of Set 13 | turayf
# Processing Record 27 of Set 13 | tortoli
# Processing Record 28 of Set 13 | marawi
# Processing Record 29 of Set 13 | waipawa
# Processing Record 30 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 13 | launceston
# Processing Record 32 of Set 13 | guarapari
# Processing Record 33 of Set 13 | eucaliptus
# Processing Record 34 of Set 13 | koulamoutou
# Processing Record 35 of Set 13 | omboue
# Processing Record 36 of Set 13 | lakes entrance
# Processing Record 37 of Set 13 | nioro
# Processing Record 38 of Set 13 | jiaozuo
# Processing Record 39 of Set 13 | mandali
# Processing Record 40 of Set 13 | amapa
# Processing Record 41 of Set 13 | smithers
# Processing Record 42 of Set 13 | muros
# Processing Record 43 of Set 13 | berdigestyakh
# Processing Record 44 of Set 13 | toamasina
# Processing Record 45 of Set 13 | parabel
# Processing Record 46 of Set 13 | tsaratanana
# Processing Record 47 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 13 | aswan
# Processing Record 49 of Set 13 | kushima
# Processing Record 50 of Set 13 | yuanping
# Processing Record 1 of Set 14 | bud
# Processing Record 2 of Set 14 | kungurtug
# Processing Record 3 of Set 14 | coswig
# Processing Record 4 of Set 14 | kobelyaky
# Processing Record 5 of Set 14 | dvorichna
# Processing Record 6 of Set 14 | dordrecht
# Processing Record 7 of Set 14 | machhlishahr
# Processing Record 8 of Set 14 | mazarron
# Processing Record 9 of Set 14 | pedasi
# Processing Record 10 of Set 14 | buta
# Processing Record 11 of Set 14 | ostrowiec swietokrzyski
# Processing Record 12 of Set 14 | williamsport
# Processing Record 13 of Set 14 | matara
# Processing Record 14 of Set 14 | bartlesville
# Processing Record 15 of Set 14 | saint john
# Processing Record 16 of Set 14 | dong hoi
# Processing Record 17 of Set 14 | humaita
# Processing Record 18 of Set 14 | gonen
# Processing Record 19 of Set 14 | tuatapere
# Processing Record 20 of Set 14 | mehamn
# Processing Record 21 of Set 14 | shimanovsk
# Processing Record 22 of Set 14 | barra do garcas
# Processing Record 23 of Set 14 | independence
# Processing Record 24 of Set 14 | srednekolymsk
# Processing Record 25 of Set 14 | dondo
# Processing Record 26 of Set 14 | mitsamiouli
# Processing Record 27 of Set 14 | parichha
# Processing Record 28 of Set 14 | waitati
# Processing Record 29 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 14 | mubende
# Processing Record 31 of Set 14 | puerto leguizamo
# Processing Record 32 of Set 14 | zyryanka
# Processing Record 33 of Set 14 | ramgarh
# Processing Record 34 of Set 14 | chifeng
# Processing Record 35 of Set 14 | kenai
# Processing Record 36 of Set 14 | nagtipunan
# Processing Record 37 of Set 14 | yablonovo
# Processing Record 38 of Set 14 | miraflores
# Processing Record 39 of Set 14 | stornoway
# Processing Record 40 of Set 14 | ostrovskoye
# Processing Record 41 of Set 14 | quang ngai
# Processing Record 42 of Set 14 | passa quatro
# Processing Record 43 of Set 14 | monroe
# Processing Record 44 of Set 14 | laguna
# Processing Record 45 of Set 14 | neyshabur
# Processing Record 46 of Set 14 | magdiwang
# Processing Record 47 of Set 14 | aksarka
# Processing Record 48 of Set 14 | sanmenxia
# Processing Record 49 of Set 14 | novoagansk
# Processing Record 50 of Set 14 | nichinan
# Processing Record 1 of Set 15 | thinadhoo
# Processing Record 2 of Set 15 | noyabrsk
# Processing Record 3 of Set 15 | terney
# Processing Record 4 of Set 15 | wickede
# Processing Record 5 of Set 15 | flinders
# Processing Record 6 of Set 15 | san jose
# Processing Record 7 of Set 15 | tautira
# Processing Record 8 of Set 15 | marsa matruh
# Processing Record 9 of Set 15 | wattegama
# Processing Record 10 of Set 15 | mujiayingzi
# Processing Record 11 of Set 15 | hobbs
# Processing Record 12 of Set 15 | oban
# Processing Record 13 of Set 15 | juneau
# Processing Record 14 of Set 15 | beypur
# City not found. Skipping...
# Processing Record 15 of Set 15 | coruripe
# Processing Record 16 of Set 15 | kimbe
# Processing Record 17 of Set 15 | sedam
# Processing Record 18 of Set 15 | baruun-urt
# Processing Record 19 of Set 15 | husavik
# Processing Record 20 of Set 15 | cozumel
# Processing Record 21 of Set 15 | soligalich
# Processing Record 22 of Set 15 | perivolion
# Processing Record 23 of Set 15 | sibu
# Processing Record 24 of Set 15 | menongue
# Processing Record 25 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 26 of Set 15 | roros
# Processing Record 27 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 15 | yellapur
# Processing Record 29 of Set 15 | maniitsoq
# Processing Record 30 of Set 15 | santa marta de tormes
# Processing Record 31 of Set 15 | emba
# Processing Record 32 of Set 15 | tabory
# Processing Record 33 of Set 15 | ishigaki
# Processing Record 34 of Set 15 | tynda
# Processing Record 35 of Set 15 | cap malheureux
# Processing Record 36 of Set 15 | shetpe
# Processing Record 37 of Set 15 | mastic beach
# Processing Record 38 of Set 15 | bitung
# Processing Record 39 of Set 15 | burnie
# Processing Record 40 of Set 15 | bambari
# Processing Record 41 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 15 | srivardhan
# Processing Record 43 of Set 15 | maicao
# Processing Record 44 of Set 15 | alvdal
# Processing Record 45 of Set 15 | chimbote
# Processing Record 46 of Set 15 | rimouski
# Processing Record 47 of Set 15 | sao joao da barra
# Processing Record 48 of Set 15 | scarborough
# Processing Record 49 of Set 15 | port-gentil
# Processing Record 50 of Set 15 | nizwa
# Processing Record 1 of Set 16 | townsville
# Processing Record 2 of Set 16 | do gonbadan
# Processing Record 3 of Set 16 | burg
# Processing Record 4 of Set 16 | pasighat
# Processing Record 5 of Set 16 | balaipungut
# Processing Record 6 of Set 16 | hobyo
# Processing Record 7 of Set 16 | atambua
# Processing Record 8 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 16 | vila
# Processing Record 10 of Set 16 | klyuchi
# Processing Record 11 of Set 16 | grand junction
# Processing Record 12 of Set 16 | sioux lookout
# Processing Record 13 of Set 16 | kendal
# Processing Record 14 of Set 16 | kyabe
# Processing Record 15 of Set 16 | tevaitoa
# Processing Record 16 of Set 16 | pagudpud
# Processing Record 17 of Set 16 | mossendjo
# Processing Record 18 of Set 16 | krasnorechenskiy
# Processing Record 19 of Set 16 | tulun
# Processing Record 20 of Set 16 | ahipara
# Processing Record 21 of Set 16 | buchanan
# Processing Record 22 of Set 16 | foix
# Processing Record 23 of Set 16 | el alto
# Processing Record 24 of Set 16 | neftcala
# Processing Record 25 of Set 16 | pakxan
# Processing Record 26 of Set 16 | simi
# Processing Record 27 of Set 16 | kurchum
# Processing Record 28 of Set 16 | thunder bay
# Processing Record 29 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 16 | filingue
# Processing Record 31 of Set 16 | zyryanskoye
# Processing Record 32 of Set 16 | berlevag
# Processing Record 33 of Set 16 | inhambane
# Processing Record 34 of Set 16 | severo-kurilsk
# Processing Record 35 of Set 16 | coihaique
# Processing Record 36 of Set 16 | avera
# Processing Record 37 of Set 16 | tartagal
# Processing Record 38 of Set 16 | mandiana
# Processing Record 39 of Set 16 | teknaf
# Processing Record 40 of Set 16 | gangotri
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0       Marabba      SD  12.3500   32.1833    105.93        10          10
# 1        Barrow      US  71.2906 -156.7887     -6.83        93          97
# 2  Punta Arenas      CL -53.1500  -70.9167     46.11        55         100
# 3      Ambilobe      MG -13.2000   49.0500     77.72        88          60
# 4       Rikitea      PF -23.1203 -134.9692     78.67        74           1
# 5         Rocha      UY -34.4833  -54.3333     78.93        44           3
# 6     Mount Isa      AU -20.7333  139.5000     85.77        28          50
# 7        Tahara      JP  34.6667  137.2667     62.55        29         100
# 8     Busselton      AU -33.6500  115.3333     57.13        72          97
# 9       Taksimo      RU  56.3444  114.8794     18.66        86          94
#
#    Wind Speed Current Description
# 0        3.62           clear sky
# 1        8.93     overcast clouds
# 2        9.15     overcast clouds
# 3        2.04       broken clouds
# 4       16.28          light rain
# 5       11.23           clear sky
# 6        6.91    scattered clouds
# 7        4.81     overcast clouds
# 8        5.10          light rain
# 9        2.86     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
